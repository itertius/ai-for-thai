# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pickle

# %%
# !ls ../Data
# Out:
# benchpress  deadlift    merge.ipynb squat

# %%
bp_df = pd.read_csv('../Data/benchpress/benchpress_coords.csv')
dl_df = pd.read_csv('../Data/deadlift/deadlift_coords.csv')
sq_df = pd.read_csv('../Data/squat/squat_coords.csv')

# %% [markdown]
# ## Benchpress

# %%
X = bp_df.drop('class', axis=1)
y = bp_df['class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression(max_iter=1000)),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algorithm, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algorithm] = model

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression(max_iter=1000))]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['b_arms_spread_down', 'b_excessive_arch_down', 'b_arms_spread_up',
#        'b_correct_down', 'b_excessive_arch_down', 'b_arms_spread_down',
#        'b_excessive_arch_down', 'b_arms_spread_up', 'b_arms_spread_up',
#        'b_excessive_arch_up', 'b_arms_spread_up', 'b_arms_spread_down',
#        'b_arms_spread_up', 'b_correct_down', 'b_arms_spread_up',
#        'b_arms_spread_up', 'b_arms_spread_up', 'b_excessive_arch_up',
#        'b_correct_down', 'b_excessive_arch_down', 'b_excessive_arch_down',
#        'b_excessive_arch_down', 'b_excessive_arch_up',
#        'b_excessive_arch_up', 'b_correct_up', 'b_excessive_arch_down',
#        'b_arms_spread_down', 'b_excessive_arch_down', 'b_correct_up',
#        'b_excessive_arch_up', 'b_arms_spread_down', 'b_correct_down',
#        'b_excessive_arch_down', 'b_correct_up', 'b_arms_spread_down',
#        'b_correct_up', 'b_correct_down', 'b_correct_down',
#        'b_excessive_arch_down', 'b_arms_spread_up',
#        'b_excessive_arch_down', 'b_excessive_arch_up', 'b_arms_spread_up',
#        'b_correct_down', 'b_correct_down', 'b_correct_down',
#        'b_arms_spread_down', 'b_correct_down', 'b_arms_spread_up',
#        'b_excessive_arch_down', 'b_correct_down', 'b_arms_spread_up',
#        'b_excessive_arch_down', 'b_excessive_arch_up',
#        'b_arms_spread_down', 'b_correct_down', 'b_excessive_arch_down',
#        'b_excessive_arch_down', 'b_arms_spread_up', 'b_correct_up',
#        'b_correct_up', 'b_correct_down', 'b_arms_spread_down',
#        'b_excessive_arch_down', 'b_arms_spread_up', 'b_arms_spread_down',
#        'b_correct_down', 'b_correct_up', 'b_excessive_arch_up',
#        'b_correct_up', 'b_arms_spread_down', 'b_excessive_arch_up',
#        'b_arms_spread_down', 'b_excessive_arch_up', 'b_arms_spread_up',
#        'b_arms_spread_up', 'b_excessive_arch_up', 'b_arms_spread_down',
#        'b_arms_spread_up', 'b_correct_up', 'b_excessive_arch_up',
#        'b_arms_spread_down', 'b_arms_spread_down', 'b_excessive_arch_up',
#        'b_arms_spread_down', 'b_correct_up', 'b_arms_spread_up',
#        'b_arms_spread_down', 'b_excessive_arch_down', 'b_arms_spread_up',
#        'b_excessive_arch_up', 'b_correct_down', 'b_arms_spread_down',
#        'b_correct_up', 'b_excessive_arch_up', 'b_arms_spread_down',
#        'b_arms_spread_down', 'b_arms_spread_up', 'b_excessive_arch_down',
#        'b_arms_spread_up', 'b_excessive_arch_down', 'b_arms_spread_down',
#        'b_arms_spread_up', 'b_correct_up', 'b_correct_down',
#        'b_excessive_arch_up', 'b_correct_up', 'b_correct_down',
#        'b_correct_up', 'b_correct_down', 'b_correct_down',
#        'b_arms_spread_up', 'b_correct_up', 'b_arms_spread_up',
#        'b_excessive_arch_down', 'b_excessive_arch_up', 'b_arms_spread_up',
#        'b_arms_spread_down', 'b_correct_down', 'b_correct_down',
#        'b_arms_spread_down', 'b_excessive_arch_up', 'b_excessive_arch_up',
#        'b_correct_down', 'b_excessive_arch_up', 'b_correct_up',
#        'b_excessive_arch_up', 'b_arms_spread_up', 'b_excessive_arch_down',
#        'b_arms_spread_up', 'b_excessive_arch_up', 'b_arms_spread_up',
#        'b_arms_spread_down', 'b_correct_down', 'b_correct_down',
#        'b_arms_spread_down', 'b_excessive_arch_up', 'b_correct_down',
#        'b_excessive_arch_down', 'b_arms_spread_down',
#        'b_arms_spread_down', 'b_excessive_arch_up', 'b_excessive_arch_up',
#        'b_arms_spread_up', 'b_arms_spread_up', 'b_arms_spread_down',
#        'b_correct_up', 'b_correct_down', 'b_correct_up', 'b_correct_down',
#        'b_arms_spread_down', 'b_arms_spread_up', 'b_arms_spread_down',
#        'b_excessive_arch_up', 'b_arms_spread_down', 'b_arms_spread_up',
#        'b_arms_spread_down', 'b_arms_spread_down', 'b_correct_up',
#        'b_correct_up', 'b_arms_spread_down', 'b_correct_up',
#        'b_correct_up', 'b_arms_spread_down', 'b_excessive_arch_up',
#        'b_arms_spread_down', 'b_correct_down', 'b_arms_spread_down',
#        'b_excessive_arch_up', 'b_correct_up', 'b_correct_down',
#        'b_excessive_arch_down', 'b_excessive_arch_up',
#        'b_excessive_arch_down', 'b_excessive_arch_down',
#        'b_arms_spread_down', 'b_excessive_arch_down', 'b_arms_spread_up',
#        'b_arms_spread_up', 'b_arms_spread_up', 'b_excessive_arch_down',
#        'b_correct_down', 'b_correct_down', 'b_arms_spread_down',
#        'b_correct_up', 'b_arms_spread_up', 'b_excessive_arch_down',
#        'b_excessive_arch_down', 'b_arms_spread_down', 'b_correct_up',
#        'b_excessive_arch_up', 'b_correct_down', 'b_arms_spread_down',
#        'b_arms_spread_up', 'b_correct_down', 'b_arms_spread_down',
#        'b_correct_up', 'b_excessive_arch_up', 'b_arms_spread_down',
#        'b_correct_down', 'b_excessive_arch_down', 'b_excessive_arch_up',
#        'b_correct_down', 'b_correct_down', 'b_arms_spread_up',
#        'b_arms_spread_down', 'b_excessive_arch_up', 'b_correct_up',
#        'b_arms_spread_up', 'b_correct_up', 'b_arms_spread_down',
#        'b_correct_up', 'b_excessive_arch_up', 'b_excessive_arch_down',
#        'b_excessive_arch_down', 'b_arms_spread_up', 'b_arms_spread_down',
#        'b_excessive_arch_up', 'b_correct_up', 'b_excessive_arch_up',
#        'b_arms_spread_down', 'b_arms_spread_up', 'b_arms_spread_up',
#        'b_excessive_arch_down', 'b_correct_up', 'b_arms_spread_up',
#        'b_correct_down', 'b_correct_up', 'b_excessive_arch_up',
#        'b_excessive_arch_down', 'b_excessive_arch_down',
#        'b_arms_spread_up', 'b_excessive_arch_down', 'b_correct_up',
#        'b_excessive_arch_down', 'b_excessive_arch_down',
#        'b_excessive_arch_down', 'b_arms_spread_down', 'b_arms_spread_up',
#        'b_correct_down', 'b_correct_down', 'b_correct_down',
#        'b_arms_spread_down', 'b_excessive_arch_down', 'b_arms_spread_up',
#        'b_excessive_arch_down', 'b_arms_spread_up', 'b_arms_spread_down',
#        'b_correct_down', 'b_excessive_arch_down', 'b_correct_down',
#        'b_correct_down', 'b_arms_spread_up', 'b_correct_up',
#        'b_correct_up', 'b_correct_down', 'b_excessive_arch_down',
#        'b_correct_up', 'b_arms_spread_down', 'b_arms_spread_up',
#        'b_excessive_arch_down', 'b_correct_up', 'b_correct_up',
#        'b_excessive_arch_down', 'b_excessive_arch_up',
#        'b_excessive_arch_down', 'b_excessive_arch_down', 'b_correct_up',
#        'b_excessive_arch_up', 'b_correct_up', 'b_excessive_arch_up',
#        'b_arms_spread_down', 'b_excessive_arch_down',
#        'b_excessive_arch_up', 'b_correct_up', 'b_correct_down',
#        'b_arms_spread_up', 'b_excessive_arch_down', 'b_arms_spread_down',
#        'b_arms_spread_down', 'b_arms_spread_down', 'b_arms_spread_down',
#        'b_arms_spread_down', 'b_excessive_arch_down',
#        'b_excessive_arch_up', 'b_correct_down', 'b_arms_spread_down'],
#       dtype='<U21')

# %%
from sklearn.metrics import classification_report

predictions = {}

for algorithm, model in fit_models.items():
    y_pred = model.predict(X_test)
    predictions[algorithm] = y_pred 

for algorithm, y_pred in predictions.items():
    print(f'--- {algorithm} ---')
    print(classification_report(y_test, y_pred))
    print()
# Out:
# --- lr ---
#                        precision    recall  f1-score   support
#
#    b_arms_spread_down       0.92      0.90      0.91        60
#      b_arms_spread_up       0.89      0.92      0.90        51
#        b_correct_down       0.98      0.92      0.95        48
#          b_correct_up       0.95      0.97      0.96        37
# b_excessive_arch_down       0.98      0.96      0.97        51
#   b_excessive_arch_up       0.95      1.00      0.98        40
#
#              accuracy                           0.94       287
#             macro avg       0.94      0.95      0.94       287
#          weighted avg       0.94      0.94      0.94       287
#
#
# --- rc ---
#                        precision    recall  f1-score   support
#
#    b_arms_spread_down       0.95      0.92      0.93        60
#      b_arms_spread_up       0.92      0.90      0.91        51
#        b_correct_down       0.96      0.92      0.94        48
#          b_correct_up       0.88      0.97      0.92        37
# b_excessive_arch_down       0.98      0.96      0.97        51
#   b_excessive_arch_up       0.95      1.00      0.98        40
#
#              accuracy                           0.94       287
#             macro avg       0.94      0.94      0.94       287
#          weighted avg       0.94      0.94      0.94       287
#
#
# --- rf ---
#                        precision    recall  f1-score   support
#
#    b_arms_spread_down       0.98      0.93      0.96        60
#      b_arms_spread_up       0.93      0.98      0.95        51
#        b_correct_down       1.00      0.94      0.97        48
#          b_correct_up       0.95      1.00      0.97        37
# b_excessive_arch_down       0.98      0.96      0.97        51
#   b_excessive_arch_up       0.95      1.00      0.98        40
#
#              accuracy                           0.97       287
#             macro avg       0.96      0.97      0.97       287
#          weighted avg       0.97      0.97      0.97       287
#
#
# --- gb ---
#                        precision    recall  f1-score   support
#
#    b_arms_spread_down       0.96      0.83      0.89        60
#      b_arms_spread_up       0.86      0.96      0.91        51
#        b_correct_down       0.96      0.94      0.95        48
#          b_correct_up       0.95      1.00      0.97        37
# b_excessive_arch_down       0.98      0.96      0.97        51
#   b_excessive_arch_up       0.95      1.00      0.98        40
#
#              accuracy                           0.94       287
#             macro avg       0.94      0.95      0.94       287
#          weighted avg       0.94      0.94      0.94       287

# %%
metrics = {
    'accuracy': {},
    'precision': {},
    'recall': {},
    'f1-score': {}
}

for algorithm, y_pred in predictions.items():
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')

    metrics['accuracy'][algorithm] = accuracy
    metrics['precision'][algorithm] = precision
    metrics['recall'][algorithm] = recall
    metrics['f1-score'][algorithm] = f1

for metric, values in metrics.items():
    print(f'--- {metric} ---')
    for algorithm, score in values.items():
        print(f'{algorithm}: {score:.4f}')
# Out:
# --- accuracy ---
# lr: 0.9408
# rc: 0.9408
# rf: 0.9652
# gb: 0.9408
# --- precision ---
# lr: 0.9415
# rc: 0.9418
# rf: 0.9664
# gb: 0.9431
# --- recall ---
# lr: 0.9408
# rc: 0.9408
# rf: 0.9652
# gb: 0.9408
# --- f1-score ---
# lr: 0.9408
# rc: 0.9407
# rf: 0.9651
# gb: 0.9403

# %%
from sklearn.metrics import classification_report
import seaborn as sns
import matplotlib.pyplot as plt

predictions = {}

for algorithm, model in fit_models.items():
    y_pred = model.predict(X_test)
    predictions[algorithm] = y_pred

metrics = ['precision', 'recall', 'f1-score']

for metric in metrics:
    plt.figure(figsize=(12, 6))
    plt.title(f'{metric} visualization')

    for algorithm, y_pred in predictions.items():
        report = classification_report(y_test, y_pred, output_dict=True)
        metric_score = [report[label][metric] for label in report if label not in ['accuracy', 'macro avg', 'weighted avg']]
        plt.plot(bp_df['class'].unique(), metric_score, label=algorithm, marker='o', linestyle='-')

    plt.xlabel('class')
    plt.ylabel(metric)
    plt.xticks(rotation=45)
    plt.legend(loc='upper left')
    plt.grid(True)
    plt.show()

# %%
with open('./benchpress/benchpress.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# ## Deadlift

# %%
X = dl_df.drop('class', axis=1)
y = dl_df['class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression(max_iter=1000)),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algorithm, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algorithm] = model

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression(max_iter=1000))]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['d_correct_down', 'd_arms_spread_up', 'd_correct_up',
#        'd_correct_down', 'd_spine_neutral_down', 'd_spine_neutral_up',
#        'd_correct_up', 'd_correct_up', 'd_correct_down',
#        'd_arms_narrow_up', 'd_arms_spread_down', 'd_spine_neutral_down',
#        'd_correct_up', 'd_correct_up', 'd_correct_down',
#        'd_arms_spread_up', 'd_arms_spread_down', 'd_spine_neutral_up',
#        'd_spine_neutral_up', 'd_arms_narrow_up', 'd_spine_neutral_up',
#        'd_spine_neutral_down', 'd_arms_narrow_down', 'd_arms_spread_down',
#        'd_arms_spread_up', 'd_correct_down', 'd_arms_spread_down',
#        'd_correct_up', 'd_arms_narrow_up', 'd_spine_neutral_down',
#        'd_spine_neutral_down', 'd_correct_down', 'd_correct_up',
#        'd_correct_up', 'd_spine_neutral_down', 'd_correct_down',
#        'd_correct_up', 'd_correct_up', 'd_arms_narrow_up',
#        'd_correct_down', 'd_arms_narrow_up', 'd_arms_spread_up',
#        'd_arms_spread_up', 'd_arms_spread_down', 'd_arms_narrow_down',
#        'd_arms_narrow_up', 'd_spine_neutral_up', 'd_arms_narrow_down',
#        'd_arms_spread_up', 'd_correct_down', 'd_spine_neutral_down',
#        'd_correct_up', 'd_spine_neutral_down', 'd_spine_neutral_down',
#        'd_arms_narrow_down', 'd_spine_neutral_down', 'd_arms_narrow_down',
#        'd_correct_down', 'd_arms_spread_up', 'd_correct_down',
#        'd_spine_neutral_up', 'd_correct_up', 'd_correct_down',
#        'd_arms_spread_up', 'd_arms_narrow_down', 'd_spine_neutral_up',
#        'd_spine_neutral_down', 'd_arms_spread_up', 'd_spine_neutral_up',
#        'd_correct_up', 'd_arms_spread_up', 'd_arms_narrow_down',
#        'd_correct_up', 'd_spine_neutral_up', 'd_arms_spread_down',
#        'd_arms_narrow_up', 'd_correct_down', 'd_arms_narrow_up',
#        'd_arms_spread_down', 'd_spine_neutral_down', 'd_correct_up',
#        'd_correct_up', 'd_arms_narrow_up', 'd_arms_narrow_up',
#        'd_spine_neutral_down', 'd_correct_down', 'd_arms_narrow_up',
#        'd_correct_up', 'd_arms_spread_up', 'd_correct_up',
#        'd_arms_spread_up', 'd_arms_narrow_down', 'd_arms_spread_up',
#        'd_spine_neutral_up', 'd_correct_up', 'd_arms_spread_down',
#        'd_arms_narrow_down', 'd_spine_neutral_up', 'd_arms_spread_down',
#        'd_spine_neutral_down', 'd_spine_neutral_up', 'd_arms_narrow_up',
#        'd_arms_spread_down', 'd_spine_neutral_down', 'd_arms_narrow_up',
#        'd_arms_spread_up', 'd_correct_up', 'd_spine_neutral_down',
#        'd_spine_neutral_up', 'd_spine_neutral_up', 'd_spine_neutral_up',
#        'd_spine_neutral_up', 'd_spine_neutral_down', 'd_arms_narrow_up',
#        'd_arms_spread_down', 'd_spine_neutral_up', 'd_correct_down',
#        'd_spine_neutral_down', 'd_correct_up', 'd_spine_neutral_down',
#        'd_spine_neutral_down', 'd_arms_spread_up', 'd_correct_down',
#        'd_spine_neutral_down', 'd_arms_spread_up', 'd_arms_spread_down',
#        'd_arms_narrow_down', 'd_arms_narrow_up', 'd_spine_neutral_down',
#        'd_spine_neutral_up', 'd_arms_spread_up', 'd_arms_narrow_up',
#        'd_arms_spread_up', 'd_arms_spread_up', 'd_arms_spread_down',
#        'd_spine_neutral_down', 'd_arms_narrow_up', 'd_arms_spread_up',
#        'd_arms_spread_up', 'd_arms_spread_down', 'd_arms_spread_down',
#        'd_arms_spread_down', 'd_spine_neutral_down', 'd_arms_narrow_down',
#        'd_spine_neutral_up', 'd_arms_spread_up', 'd_spine_neutral_up',
#        'd_correct_up', 'd_spine_neutral_down', 'd_correct_down',
#        'd_arms_spread_down', 'd_spine_neutral_down', 'd_spine_neutral_up',
#        'd_arms_narrow_down', 'd_arms_narrow_up', 'd_arms_narrow_up',
#        'd_arms_spread_down', 'd_arms_narrow_up', 'd_spine_neutral_up',
#        'd_arms_spread_up', 'd_correct_up', 'd_arms_narrow_up',
#        'd_spine_neutral_down', 'd_arms_narrow_down', 'd_arms_narrow_up',
#        'd_arms_narrow_down', 'd_correct_up', 'd_correct_down',
#        'd_arms_narrow_up', 'd_arms_spread_down', 'd_arms_narrow_up',
#        'd_correct_down', 'd_arms_narrow_down', 'd_correct_up',
#        'd_arms_spread_up', 'd_correct_up', 'd_arms_narrow_up',
#        'd_arms_spread_down', 'd_spine_neutral_down', 'd_correct_up',
#        'd_arms_narrow_up', 'd_correct_up', 'd_spine_neutral_up',
#        'd_spine_neutral_down', 'd_arms_narrow_up', 'd_spine_neutral_up',
#        'd_correct_up', 'd_arms_narrow_down', 'd_correct_down',
#        'd_correct_down', 'd_correct_down', 'd_arms_narrow_down',
#        'd_correct_up', 'd_arms_narrow_up', 'd_correct_down',
#        'd_arms_narrow_down', 'd_correct_up', 'd_arms_spread_down',
#        'd_spine_neutral_down', 'd_correct_up', 'd_arms_spread_down',
#        'd_spine_neutral_up', 'd_spine_neutral_down', 'd_correct_down',
#        'd_spine_neutral_down', 'd_spine_neutral_down',
#        'd_arms_narrow_down', 'd_arms_spread_down', 'd_arms_spread_down',
#        'd_spine_neutral_up', 'd_arms_spread_up', 'd_spine_neutral_down',
#        'd_correct_up', 'd_arms_spread_down', 'd_correct_down',
#        'd_arms_spread_down', 'd_spine_neutral_up', 'd_arms_spread_down',
#        'd_arms_narrow_down', 'd_arms_narrow_up', 'd_arms_narrow_up',
#        'd_arms_narrow_up', 'd_spine_neutral_down', 'd_spine_neutral_down',
#        'd_correct_down', 'd_spine_neutral_down', 'd_spine_neutral_down',
#        'd_arms_spread_up', 'd_correct_up', 'd_spine_neutral_up',
#        'd_arms_narrow_down', 'd_arms_narrow_up', 'd_arms_spread_up',
#        'd_correct_down', 'd_arms_spread_down', 'd_arms_narrow_up',
#        'd_arms_spread_down', 'd_arms_spread_down', 'd_spine_neutral_up',
#        'd_correct_up', 'd_arms_narrow_up', 'd_spine_neutral_up',
#        'd_arms_narrow_down', 'd_arms_spread_up', 'd_spine_neutral_up',
#        'd_arms_spread_down', 'd_spine_neutral_up', 'd_spine_neutral_down',
#        'd_spine_neutral_down', 'd_correct_up', 'd_arms_narrow_down',
#        'd_correct_up', 'd_correct_up', 'd_arms_narrow_up',
#        'd_arms_narrow_up', 'd_arms_spread_down', 'd_correct_down',
#        'd_correct_down', 'd_arms_spread_down', 'd_spine_neutral_down',
#        'd_spine_neutral_up', 'd_arms_narrow_down', 'd_spine_neutral_up',
#        'd_arms_narrow_up', 'd_arms_narrow_up', 'd_arms_narrow_up',
#        'd_spine_neutral_up', 'd_spine_neutral_down', 'd_arms_spread_down',
#        'd_arms_narrow_down', 'd_arms_spread_down', 'd_arms_spread_down',
#        'd_correct_down', 'd_arms_narrow_up', 'd_correct_up',
#        'd_arms_spread_up', 'd_correct_down', 'd_spine_neutral_down',
#        'd_correct_up', 'd_arms_narrow_up', 'd_spine_neutral_up',
#        'd_spine_neutral_up', 'd_arms_narrow_down', 'd_correct_up',
#        'd_arms_spread_down', 'd_spine_neutral_up', 'd_arms_spread_up',
#        'd_arms_spread_down', 'd_correct_up', 'd_arms_narrow_down',
#        'd_correct_down', 'd_arms_spread_down', 'd_spine_neutral_up',
#        'd_arms_spread_up', 'd_spine_neutral_up', 'd_correct_down',
#        'd_arms_spread_up', 'd_spine_neutral_up', 'd_spine_neutral_up',
#        'd_arms_narrow_down', 'd_spine_neutral_down',
#        'd_spine_neutral_down', 'd_correct_down', 'd_spine_neutral_down',
#        'd_correct_up', 'd_correct_up', 'd_spine_neutral_up',
#        'd_arms_spread_down', 'd_arms_spread_down', 'd_arms_narrow_up',
#        'd_arms_narrow_up', 'd_arms_spread_up', 'd_correct_up',
#        'd_spine_neutral_down', 'd_spine_neutral_up', 'd_arms_narrow_up',
#        'd_arms_spread_up', 'd_spine_neutral_up', 'd_spine_neutral_down',
#        'd_arms_narrow_up', 'd_arms_narrow_down', 'd_arms_narrow_up',
#        'd_spine_neutral_down', 'd_arms_spread_down', 'd_spine_neutral_up',
#        'd_arms_spread_up', 'd_spine_neutral_down', 'd_arms_spread_down',
#        'd_arms_spread_up', 'd_arms_spread_down', 'd_correct_down',
#        'd_arms_narrow_up', 'd_arms_narrow_down', 'd_arms_spread_up',
#        'd_correct_up', 'd_arms_spread_up', 'd_arms_narrow_up',
#        'd_correct_up', 'd_spine_neutral_up', 'd_arms_narrow_down',
#        'd_arms_narrow_down', 'd_correct_down'], dtype='<U20')

# %%
from sklearn.metrics import classification_report

predictions = {}

for algorithm, model in fit_models.items():
    y_pred = model.predict(X_test)
    predictions[algorithm] = y_pred 

for algorithm, y_pred in predictions.items():
    print(f'--- {algorithm} ---')
    print(classification_report(y_test, y_pred))
    print()
# Out:
# --- lr ---
#                       precision    recall  f1-score   support
#
#   d_arms_narrow_down       0.97      0.93      0.95        40
#     d_arms_narrow_up       0.82      0.84      0.83        44
#   d_arms_spread_down       0.90      1.00      0.95        38
#     d_arms_spread_up       0.83      0.94      0.88        32
#       d_correct_down       0.97      0.91      0.94        35
#         d_correct_up       0.94      0.84      0.89        57
# d_spine_neutral_down       0.88      0.95      0.91        44
#   d_spine_neutral_up       0.88      0.83      0.85        52
#
#             accuracy                           0.90       342
#            macro avg       0.90      0.91      0.90       342
#         weighted avg       0.90      0.90      0.90       342
#
#
# --- rc ---
#                       precision    recall  f1-score   support
#
#   d_arms_narrow_down       0.97      0.78      0.86        40
#     d_arms_narrow_up       0.81      0.89      0.85        44
#   d_arms_spread_down       0.86      1.00      0.93        38
#     d_arms_spread_up       0.82      0.97      0.89        32
#       d_correct_down       0.92      0.94      0.93        35
#         d_correct_up       0.96      0.79      0.87        57
# d_spine_neutral_down       0.82      0.93      0.87        44
#   d_spine_neutral_up       0.87      0.79      0.83        52
#
#             accuracy                           0.87       342
#            macro avg       0.88      0.89      0.88       342
#         weighted avg       0.88      0.87      0.87       342
#
#
# --- rf ---
#                       precision    recall  f1-score   support
#
#   d_arms_narrow_down       0.95      0.93      0.94        40
#     d_arms_narrow_up       0.95      0.95      0.95        44
#   d_arms_spread_down       0.93      1.00      0.96        38
#     d_arms_spread_up       1.00      1.00      1.00        32
#       d_correct_down       0.94      0.97      0.96        35
#         d_correct_up       1.00      0.96      0.98        57
# d_spine_neutral_down       0.89      0.95      0.92        44
#   d_spine_neutral_up       0.96      0.88      0.92        52
#
#             accuracy                           0.95       342
#            macro avg       0.95      0.96      0.95       342
#         weighted avg       0.95      0.95      0.95       342
#
#
# --- gb ---
#                       precision    recall  f1-score   support
#
#   d_arms_narrow_down       0.95      0.88      0.91        40
#     d_arms_narrow_up       0.91      0.95      0.93        44
#   d_arms_spread_down       0.88      1.00      0.94        38
#     d_arms_spread_up       1.00      0.94      0.97        32
#       d_correct_down       1.00      0.97      0.99        35
#         d_correct_up       0.98      0.93      0.95        57
# d_spine_neutral_down       0.89      0.93      0.91        44
#   d_spine_neutral_up       0.92      0.92      0.92        52
#
#             accuracy                           0.94       342
#            macro avg       0.94      0.94      0.94       342
#         weighted avg       0.94      0.94      0.94       342

# %%
metrics = {
    'accuracy': {},
    'precision': {},
    'recall': {},
    'f1-score': {}
}

for algorithm, y_pred in predictions.items():
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')

    metrics['accuracy'][algorithm] = accuracy
    metrics['precision'][algorithm] = precision
    metrics['recall'][algorithm] = recall
    metrics['f1-score'][algorithm] = f1

for metric, values in metrics.items():
    print(f'--- {metric} ---')
    for algorithm, score in values.items():
        print(f'{algorithm}: {score:.4f}')
# Out:
# --- accuracy ---
# lr: 0.8977
# rc: 0.8743
# rf: 0.9532
# gb: 0.9386
# --- precision ---
# lr: 0.9003
# rc: 0.8816
# rf: 0.9543
# gb: 0.9408
# --- recall ---
# lr: 0.8977
# rc: 0.8743
# rf: 0.9532
# gb: 0.9386
# --- f1-score ---
# lr: 0.8974
# rc: 0.8732
# rf: 0.9532
# gb: 0.9388

# %%
from sklearn.metrics import classification_report
import seaborn as sns
import matplotlib.pyplot as plt

predictions = {}

for algorithm, model in fit_models.items():
    y_pred = model.predict(X_test)
    predictions[algorithm] = y_pred

metrics = ['precision', 'recall', 'f1-score']

for metric in metrics:
    plt.figure(figsize=(12, 6))
    plt.title(f'{metric} visualization')

    for algorithm, y_pred in predictions.items():
        report = classification_report(y_test, y_pred, output_dict=True)
        metric_score = [report[label][metric] for label in report if label not in ['accuracy', 'macro avg', 'weighted avg']]
        plt.plot(dl_df['class'].unique(), metric_score, label=algorithm, marker='o', linestyle='-')

    plt.xlabel('class')
    plt.ylabel(metric)
    plt.xticks(rotation=45)
    plt.legend(loc='upper left')
    plt.grid(True)
    plt.show()

# %%
with open('./deadlift/deadlift.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# ## Squat

# %%
X = sq_df.drop('class', axis=1)
y = sq_df['class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression(max_iter=1000)),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algorithm, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algorithm] = model

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression(max_iter=1000))]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['s_caved_in_knees_up', 's_spine_neutral_down',
#        's_spine_neutral_up', 's_spine_neutral_down', 's_spine_neutral_up',
#        's_correct_up', 's_feet_spread_up', 's_feet_spread_down',
#        's_feet_spread_down', 's_feet_spread_down',
#        's_caved_in_knees_down', 's_correct_down', 's_correct_up',
#        's_caved_in_knees_up', 's_correct_down', 's_feet_spread_up',
#        's_feet_spread_down', 's_caved_in_knees_down',
#        's_caved_in_knees_up', 's_caved_in_knees_down',
#        's_caved_in_knees_down', 's_correct_up', 's_spine_neutral_down',
#        's_feet_spread_up', 's_caved_in_knees_up', 's_caved_in_knees_up',
#        's_feet_spread_up', 's_spine_neutral_down', 's_correct_down',
#        's_spine_neutral_down', 's_caved_in_knees_down', 's_correct_up',
#        's_feet_spread_up', 's_correct_down', 's_caved_in_knees_up',
#        's_caved_in_knees_up', 's_correct_down', 's_caved_in_knees_up',
#        's_feet_spread_up', 's_correct_up', 's_feet_spread_down',
#        's_caved_in_knees_up', 's_feet_spread_up', 's_feet_spread_down',
#        's_correct_down', 's_caved_in_knees_down', 's_correct_down',
#        's_feet_spread_up', 's_spine_neutral_down', 's_spine_neutral_up',
#        's_spine_neutral_up', 's_feet_spread_down', 's_feet_spread_up',
#        's_correct_down', 's_correct_down', 's_feet_spread_down',
#        's_caved_in_knees_down', 's_feet_spread_up', 's_correct_up',
#        's_caved_in_knees_down', 's_feet_spread_up', 's_caved_in_knees_up',
#        's_correct_up', 's_correct_up', 's_correct_up',
#        's_spine_neutral_up', 's_feet_spread_up', 's_feet_spread_up',
#        's_correct_up', 's_spine_neutral_up', 's_spine_neutral_down',
#        's_caved_in_knees_down', 's_feet_spread_up',
#        's_spine_neutral_down', 's_correct_down', 's_caved_in_knees_up',
#        's_correct_up', 's_spine_neutral_down', 's_feet_spread_up',
#        's_feet_spread_up', 's_caved_in_knees_up', 's_feet_spread_down',
#        's_caved_in_knees_up', 's_caved_in_knees_down', 's_correct_up',
#        's_spine_neutral_down', 's_spine_neutral_down', 's_correct_down',
#        's_correct_down', 's_feet_spread_up', 's_feet_spread_up',
#        's_caved_in_knees_down', 's_spine_neutral_down', 's_correct_up',
#        's_correct_down', 's_spine_neutral_up', 's_spine_neutral_down',
#        's_caved_in_knees_up', 's_caved_in_knees_down', 's_correct_down',
#        's_correct_down', 's_correct_down', 's_spine_neutral_down',
#        's_caved_in_knees_up', 's_spine_neutral_down', 's_feet_spread_up',
#        's_caved_in_knees_down', 's_caved_in_knees_up',
#        's_caved_in_knees_up', 's_correct_down', 's_feet_spread_up',
#        's_caved_in_knees_up', 's_correct_up', 's_feet_spread_up',
#        's_correct_up', 's_caved_in_knees_up', 's_correct_up',
#        's_caved_in_knees_up', 's_correct_up', 's_feet_spread_down',
#        's_feet_spread_down', 's_correct_up', 's_correct_up',
#        's_correct_up', 's_caved_in_knees_up', 's_feet_spread_up',
#        's_correct_down', 's_spine_neutral_up', 's_spine_neutral_up',
#        's_caved_in_knees_up', 's_correct_down', 's_spine_neutral_up',
#        's_caved_in_knees_down', 's_caved_in_knees_down', 's_correct_up',
#        's_caved_in_knees_up', 's_caved_in_knees_down',
#        's_spine_neutral_up', 's_feet_spread_down', 's_correct_up',
#        's_feet_spread_down', 's_feet_spread_down', 's_spine_neutral_up',
#        's_caved_in_knees_down', 's_feet_spread_down', 's_correct_up',
#        's_correct_up', 's_feet_spread_down', 's_caved_in_knees_up',
#        's_spine_neutral_up', 's_feet_spread_up', 's_spine_neutral_down',
#        's_correct_down', 's_spine_neutral_down', 's_caved_in_knees_down',
#        's_correct_up', 's_correct_down', 's_spine_neutral_down',
#        's_correct_down', 's_feet_spread_down', 's_caved_in_knees_up',
#        's_caved_in_knees_down', 's_caved_in_knees_up',
#        's_caved_in_knees_down', 's_spine_neutral_up',
#        's_spine_neutral_down', 's_caved_in_knees_up',
#        's_feet_spread_down', 's_caved_in_knees_down', 's_correct_up',
#        's_feet_spread_down', 's_correct_up', 's_feet_spread_up',
#        's_spine_neutral_up', 's_correct_up', 's_caved_in_knees_down',
#        's_spine_neutral_up', 's_feet_spread_up', 's_spine_neutral_up',
#        's_feet_spread_up', 's_correct_down', 's_spine_neutral_up',
#        's_spine_neutral_up', 's_correct_up', 's_correct_up',
#        's_caved_in_knees_up', 's_spine_neutral_down',
#        's_caved_in_knees_up', 's_feet_spread_up', 's_feet_spread_up',
#        's_spine_neutral_down', 's_spine_neutral_up', 's_feet_spread_down',
#        's_caved_in_knees_up', 's_caved_in_knees_down',
#        's_spine_neutral_up', 's_correct_down', 's_spine_neutral_down',
#        's_caved_in_knees_down', 's_correct_down', 's_feet_spread_down',
#        's_correct_up', 's_spine_neutral_down', 's_feet_spread_down',
#        's_feet_spread_up', 's_correct_down', 's_spine_neutral_up',
#        's_correct_up', 's_spine_neutral_up', 's_caved_in_knees_up',
#        's_spine_neutral_up', 's_spine_neutral_up', 's_spine_neutral_up',
#        's_feet_spread_up', 's_spine_neutral_up', 's_correct_down',
#        's_spine_neutral_up', 's_caved_in_knees_up', 's_feet_spread_up',
#        's_feet_spread_down', 's_feet_spread_up', 's_caved_in_knees_down',
#        's_caved_in_knees_down', 's_feet_spread_up',
#        's_spine_neutral_down', 's_caved_in_knees_up',
#        's_caved_in_knees_up', 's_caved_in_knees_up',
#        's_spine_neutral_down', 's_caved_in_knees_down',
#        's_caved_in_knees_down', 's_caved_in_knees_down',
#        's_caved_in_knees_up', 's_caved_in_knees_down',
#        's_spine_neutral_down', 's_correct_up', 's_correct_up',
#        's_caved_in_knees_down', 's_spine_neutral_up',
#        's_feet_spread_down', 's_spine_neutral_up',
#        's_caved_in_knees_down', 's_spine_neutral_down',
#        's_feet_spread_up', 's_correct_up', 's_spine_neutral_down',
#        's_feet_spread_down', 's_feet_spread_down', 's_spine_neutral_up',
#        's_feet_spread_down', 's_correct_up', 's_caved_in_knees_up',
#        's_caved_in_knees_down', 's_feet_spread_down',
#        's_spine_neutral_down', 's_correct_up', 's_correct_up',
#        's_caved_in_knees_up', 's_caved_in_knees_down',
#        's_caved_in_knees_up', 's_feet_spread_up', 's_correct_down',
#        's_feet_spread_down', 's_caved_in_knees_up', 's_caved_in_knees_up',
#        's_spine_neutral_up', 's_spine_neutral_up',
#        's_caved_in_knees_down', 's_caved_in_knees_down', 's_correct_down',
#        's_caved_in_knees_down', 's_correct_down', 's_correct_up',
#        's_caved_in_knees_down', 's_spine_neutral_up',
#        's_feet_spread_down', 's_spine_neutral_down', 's_spine_neutral_up',
#        's_correct_up'], dtype='<U21')

# %%
from sklearn.metrics import classification_report

predictions = {}

for algorithm, model in fit_models.items():
    y_pred = model.predict(X_test)
    predictions[algorithm] = y_pred 

for algorithm, y_pred in predictions.items():
    print(f'--- {algorithm} ---')
    print(classification_report(y_test, y_pred))
    print()
# Out:
# --- lr ---
#                        precision    recall  f1-score   support
#
# s_caved_in_knees_down       1.00      1.00      1.00        38
#   s_caved_in_knees_up       1.00      1.00      1.00        41
#        s_correct_down       1.00      1.00      1.00        30
#          s_correct_up       0.98      0.98      0.98        42
#    s_feet_spread_down       1.00      1.00      1.00        29
#      s_feet_spread_up       1.00      1.00      1.00        36
#  s_spine_neutral_down       0.94      1.00      0.97        30
#    s_spine_neutral_up       0.97      0.91      0.94        33
#
#              accuracy                           0.99       279
#             macro avg       0.99      0.99      0.99       279
#          weighted avg       0.99      0.99      0.99       279
#
#
# --- rc ---
#                        precision    recall  f1-score   support
#
# s_caved_in_knees_down       1.00      1.00      1.00        38
#   s_caved_in_knees_up       1.00      1.00      1.00        41
#        s_correct_down       0.97      0.97      0.97        30
#          s_correct_up       1.00      0.95      0.98        42
#    s_feet_spread_down       0.97      1.00      0.98        29
#      s_feet_spread_up       1.00      0.97      0.99        36
#  s_spine_neutral_down       1.00      1.00      1.00        30
#    s_spine_neutral_up       0.94      1.00      0.97        33
#
#              accuracy                           0.99       279
#             macro avg       0.98      0.99      0.99       279
#          weighted avg       0.99      0.99      0.99       279
#
#
# --- rf ---
#                        precision    recall  f1-score   support
#
# s_caved_in_knees_down       1.00      1.00      1.00        38
#   s_caved_in_knees_up       1.00      1.00      1.00        41
#        s_correct_down       1.00      1.00      1.00        30
#          s_correct_up       1.00      1.00      1.00        42
#    s_feet_spread_down       1.00      1.00      1.00        29
#      s_feet_spread_up       1.00      1.00      1.00        36
#  s_spine_neutral_down       0.94      0.97      0.95        30
#    s_spine_neutral_up       0.97      0.94      0.95        33
#
#              accuracy                           0.99       279
#             macro avg       0.99      0.99      0.99       279
#          weighted avg       0.99      0.99      0.99       279
#
#
# --- gb ---
#                        precision    recall  f1-score   support
#
# s_caved_in_knees_down       1.00      1.00      1.00        38
#   s_caved_in_knees_up       1.00      0.98      0.99        41
#        s_correct_down       0.97      1.00      0.98        30
#          s_correct_up       1.00      1.00      1.00        42
#    s_feet_spread_down       1.00      1.00      1.00        29
#      s_feet_spread_up       1.00      1.00      1.00        36
#  s_spine_neutral_down       0.93      0.93      0.93        30
#    s_spine_neutral_up       0.94      0.94      0.94        33
#
#              accuracy                           0.98       279
#             macro avg       0.98      0.98      0.98       279
#          weighted avg       0.98      0.98      0.98       279

# %%
metrics = {
    'accuracy': {},
    'precision': {},
    'recall': {},
    'f1-score': {}
}

for algorithm, y_pred in predictions.items():
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')

    metrics['accuracy'][algorithm] = accuracy
    metrics['precision'][algorithm] = precision
    metrics['recall'][algorithm] = recall
    metrics['f1-score'][algorithm] = f1

for metric, values in metrics.items():
    print(f'--- {metric} ---')
    for algorithm, score in values.items():
        print(f'{algorithm}: {score:.4f}')
# Out:
# --- accuracy ---
# lr: 0.9857
# rc: 0.9857
# rf: 0.9892
# gb: 0.9821
# --- precision ---
# lr: 0.9859
# rc: 0.9862
# rf: 0.9894
# gb: 0.9822
# --- recall ---
# lr: 0.9857
# rc: 0.9857
# rf: 0.9892
# gb: 0.9821
# --- f1-score ---
# lr: 0.9856
# rc: 0.9857
# rf: 0.9893
# gb: 0.9821

# %%
from sklearn.metrics import classification_report
import seaborn as sns
import matplotlib.pyplot as plt

predictions = {}

for algorithm, model in fit_models.items():
    y_pred = model.predict(X_test)
    predictions[algorithm] = y_pred

metrics = ['precision', 'recall', 'f1-score']

for metric in metrics:
    plt.figure(figsize=(12, 6))
    plt.title(f'{metric} visualization')

    for algorithm, y_pred in predictions.items():
        report = classification_report(y_test, y_pred, output_dict=True)
        metric_score = [report[label][metric] for label in report if label not in ['accuracy', 'macro avg', 'weighted avg']]
        plt.plot(dl_df['class'].unique(), metric_score, label=algorithm, marker='o', linestyle='-')

    plt.xlabel('class')
    plt.ylabel(metric)
    plt.xticks(rotation=45)
    plt.legend(loc='upper left')
    plt.grid(True)
    plt.show()

# %%
with open('./squat/squat.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)
